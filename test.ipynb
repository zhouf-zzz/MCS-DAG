# %%
from experiment import *

# %%
# ts = Drs_gengerate(50, 0.1* node_number, 2, 0.5, node_number)
# sys_uLO, sys_uHI = cal_sys_uti(ts)
# #print(sys_uLO, sys_uHI)
# task_set = ts.HI.union(ts.LO)
# ts.priority_assignment_DM_HI(task_set,0)
# FF_DU_mapping_list = FF_DP(ts, amc_rtb_wcrt)
# with open("./test_result/FF_DU_mapping_list.txt", "w") as file:
#     for data in FF_DU_mapping_list:
#         file.write(str(data) + "\n")
# FF_DU_mapping_list_1 = FF_DP(ts, new_wcrt_1)
# with open("./test_result/FF_DU_mapping_list_1.txt", "w") as file:
#     for data in FF_DU_mapping_list_1:
#         file.write(str(data) + "\n")
# FF_DU_mapping_list_2 = FF_DP(ts, new_wcrt_2)
# with open("./test_result/FF_DU_mapping_list_2.txt", "w") as file:
#     for data in FF_DU_mapping_list_2:
#         file.write(str(data) + "\n")
# FF_DU_mapping_list_3 = FF_DP(ts, new_wcrt_3)
# with open("./test_result/FF_DU_mapping_list_3.txt", "w") as file:
#     for data in FF_DU_mapping_list_3:
#         file.write(str(data) + "\n")
# FF_DU_mapping_list_4 = FF_DP(ts, new_wcrt_4)
# with open("./test_result/FF_DU_mapping_list_4.txt", "w") as file:
#     for data in FF_DU_mapping_list_4:
#         file.write(str(data) + "\n")
# FF_DU_mapping_list_5 = FF_DP(ts, new_wcrt_5)
# with open("./test_result/FF_DU_mapping_list_5.txt", "w") as file:
#     for data in FF_DU_mapping_list_5:
#         file.write(str(data) + "\n")
# content_task_list = get_content_task_set(FF_DU_mapping_list_1, task_set, len(task_set))
# with open("./test_result/content_task_list.txt", "w") as file:
#     for data in content_task_list:
#         file.write(str(data) + "\n")

# with open("./test_result/wcrt.txt", "w") as file:
#     for task in task_set:
#         content_task_set_HI_pri = set()
#         for id in content_task_list[task.id]:
#             content_task = ts.get_task_by_id(id)
#         if content_task.pri > task.pri:
#             content_task_set_HI_pri.add(content_task)
#         wcrt = amc_rtb_wcrt(ts, task, content_task_set_HI_pri)
#         wcrt_1 = new_wcrt_1(ts, task, content_task_set_HI_pri)
#         wcrt_2 = new_wcrt_2(ts, task, content_task_set_HI_pri)
#         wcrt_3 = new_wcrt_3(ts, task, content_task_set_HI_pri)
#         wcrt_4 = new_wcrt_4(ts, task, content_task_set_HI_pri)
#         wcrt_5 = new_wcrt_5(ts, task, content_task_set_HI_pri)
#         if wcrt != wcrt_1 or wcrt != wcrt_2 or wcrt != wcrt_3 or wcrt != wcrt_4 or wcrt != wcrt_5:
#             file.write(str(task.id)+ "  " + str(task.cri)+ "  " + str(task.eLO)+ "  " + str(task.eHI)+ "  " + str(wcrt)+ "  " + str(wcrt_1) + "  " + str(wcrt_2) + "  " + str(wcrt_3) + \
#                         "  " + str(wcrt_4) + "  " + str(wcrt_5) + "\n")
# with open("./test_result/task_list.txt", "w") as file:
#     for task in task_set:
#         file.write(task.info() + "\n")

# %%
mapping_uti_exper()
# Out:
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [02:16<00:00,  7.33items/s]
# 系统利用率：0.2  FF_DU可调度率：712  FF_DP可调度率：1000  BF_DU可调度率：770  BF_DP可调度率：997  WF_DU可调度率：968  WF_DP可调度率：960  BF_FF_DP可调度率：999
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [02:05<00:00,  7.99items/s]
# 系统利用率：0.25  FF_DU可调度率：580  FF_DP可调度率：999  BF_DU可调度率：614  BF_DP可调度率：963  WF_DU可调度率：821  WF_DP可调度率：867  BF_FF_DP可调度率：984
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [01:55<00:00,  8.68items/s]
# 系统利用率：0.30000000000000004  FF_DU可调度率：476  FF_DP可调度率：973  BF_DU可调度率：480  BF_DP可调度率：847  WF_DU可调度率：562  WF_DP可调度率：665  BF_FF_DP可调度率：913
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [01:46<00:00,  9.38items/s]
# 系统利用率：0.35000000000000003  FF_DU可调度率：328  FF_DP可调度率：876  BF_DU可调度率：370  BF_DP可调度率：698  WF_DU可调度率：281  WF_DP可调度率：391  BF_FF_DP可调度率：773
# ...

# %%
mapping_CP_exper()
mapping_CF_exper()
#mapping_uti_exper_time()
# Out:
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [01:47<00:00,  9.33items/s]
# 系统利用率：0.3  FF_DU可调度率：266  FF_DP可调度率：918  BF_DU可调度率：362  BF_DP可调度率：759  WF_DU可调度率：309  WF_DP可调度率：428  BF_FF_DP可调度率：897
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [01:42<00:00,  9.71items/s]
# 系统利用率：0.35  FF_DU可调度率：274  FF_DP可调度率：891  BF_DU可调度率：303  BF_DP可调度率：701  WF_DU可调度率：258  WF_DP可调度率：380  BF_FF_DP可调度率：842
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [01:39<00:00, 10.07items/s]
# 系统利用率：0.4  FF_DU可调度率：248  FF_DP可调度率：820  BF_DU可调度率：288  BF_DP可调度率：627  WF_DU可调度率：195  WF_DP可调度率：321  BF_FF_DP可调度率：752
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [01:33<00:00, 10.66items/s]
# 系统利用率：0.45  FF_DU可调度率：223  FF_DP可调度率：789  BF_DU可调度率：256  BF_DP可调度率：605  WF_DU可调度率：182  WF_DP可调度率：260  BF_FF_DP可调度率：678
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [01:27<00:00, 11.39items/s]
# ...

# %%
pri_uti_exper()
# Out:
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [00:29<00:00, 34.21items/s]
# 系统利用率：0.2  DM可调度率：1000  CRMS可调度率：892  Slack可调度率：998
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [00:30<00:00, 33.15items/s]
# 系统利用率：0.25  DM可调度率：1000  CRMS可调度率：789  Slack可调度率：996
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [00:30<00:00, 32.93items/s]
# 系统利用率：0.30000000000000004  DM可调度率：970  CRMS可调度率：618  Slack可调度率：963
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [00:29<00:00, 33.34items/s]
# 系统利用率：0.35000000000000003  DM可调度率：885  CRMS可调度率：413  Slack可调度率：818
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [00:28<00:00, 34.79items/s]
# 系统利用率：0.4  DM可调度率：680  CRMS可调度率：273  Slack可调度率：606
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [00:25<00:00, 39.15items/s]
# 系统利用率：0.45  DM可调度率：385  CRMS可调度率：143  Slack可调度率：323
# ...

# %%
#wcrt_uti_exper_BF()
# Out:
# Processing:   0%|                                                        | 0/100 [00:00<?, ?items/s]f:\program\anaconda\lib\site-packages\numpy\linalg\linalg.py:2158: RuntimeWarning: overflow encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# Processing: 100%|██████████████████████████████████████████| 100/100 [11:44:04<00:00, 422.44s/items]
# 系统利用率：0.3  amc-rtb可调度率：100  amc-rtb-pr-unit可调度率：6  amc-rtb-pr可调度率：99
# Processing: 100%|██████████████████████████████████████████| 100/100 [12:24:45<00:00, 446.86s/items]
# 系统利用率：0.32  amc-rtb可调度率：100  amc-rtb-pr-unit可调度率：1  amc-rtb-pr可调度率：97
# Processing: 100%|██████████████████████████████████████████| 100/100 [11:44:30<00:00, 422.70s/items]
# 系统利用率：0.33999999999999997  amc-rtb可调度率：91  amc-rtb-pr-unit可调度率：1  amc-rtb-pr可调度率：96
# Processing: 100%|██████████████████████████████████████████| 100/100 [11:29:58<00:00, 413.99s/items]
# 系统利用率：0.36  amc-rtb可调度率：80  amc-rtb-pr-unit可调度率：0  amc-rtb-pr可调度率：87
# ...

# %%
wcrt_uti_exper_FF()
# Out:
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [05:09<00:00,  3.23items/s]
# 系统利用率：0.2  amc-rtb可调度率：1000  amc-rtb-pr可调度率：1000
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [05:58<00:00,  2.79items/s]
# 系统利用率：0.25  amc-rtb可调度率：988  amc-rtb-pr可调度率：998
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [06:26<00:00,  2.59items/s]
# 系统利用率：0.30000000000000004  amc-rtb可调度率：968  amc-rtb-pr可调度率：999
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [06:40<00:00,  2.50items/s]
# 系统利用率：0.35000000000000003  amc-rtb可调度率：846  amc-rtb-pr可调度率：995
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [07:22<00:00,  2.26items/s]
# 系统利用率：0.4  amc-rtb可调度率：612  amc-rtb-pr可调度率：981
# Processing: 100%|████████████████████████████████████████████| 1000/1000 [07:27<00:00,  2.23items/s]
# 系统利用率：0.45  amc-rtb可调度率：349  amc-rtb-pr可调度率：947
# ...

# %%
# 任务：150 硬件：10 * 10
# 系统利用率：0.2  FF_DU可调度率：1000  FF_DP可调度率：1000  BF_DU可调度率：1000  BF_DP可调度率：1000  WF_DU可调度率：842  WF_DP可调度率：910  BF_FF_DP可调度率：1000
# 系统利用率：0.22  FF_DU可调度率：998  FF_DP可调度率：1000  BF_DU可调度率：1000  BF_DP可调度率：1000  WF_DU可调度率：597  WF_DP可调度率：728  BF_FF_DP可调度率：1000
# 系统利用率：0.24000000000000002  FF_DU可调度率：995  FF_DP可调度率：1000  BF_DU可调度率：1000  BF_DP可调度率：1000  WF_DU可调度率：340  WF_DP可调度率：488  BF_FF_DP可调度率：1000
# 系统利用率：0.26  FF_DU可调度率：983  FF_DP可调度率：1000  BF_DU可调度率：993  BF_DP可调度率：1000  WF_DU可调度率：186  WF_DP可调度率：309  BF_FF_DP可调度率：1000
# 系统利用率：0.28  FF_DU可调度率：937  FF_DP可调度率：1000  BF_DU可调度率：962  BF_DP可调度率：1000  WF_DU可调度率：88  WF_DP可调度率：149  BF_FF_DP可调度率：1000
# 系统利用率：0.30000000000000004  FF_DU可调度率：819  FF_DP可调度率：1000  BF_DU可调度率：916  BF_DP可调度率：1000  WF_DU可调度率：23  WF_DP可调度率：64  BF_FF_DP可调度率：1000
# 系统利用率：0.32  FF_DU可调度率：654  FF_DP可调度率：1000  BF_DU可调度率：800  BF_DP可调度率：1000  WF_DU可调度率：7  WF_DP可调度率：22  BF_FF_DP可调度率：1000
# 系统利用率：0.34  FF_DU可调度率：479  FF_DP可调度率：999  BF_DU可调度率：680  BF_DP可调度率：996  WF_DU可调度率：0  WF_DP可调度率：6  BF_FF_DP可调度率：992
# 系统利用率：0.36  FF_DU可调度率：286  FF_DP可调度率：998  BF_DU可调度率：508  BF_DP可调度率：991  WF_DU可调度率：0  WF_DP可调度率：0  BF_FF_DP可调度率：982
# 系统利用率：0.38  FF_DU可调度率：158  FF_DP可调度率：985  BF_DU可调度率：328  BF_DP可调度率：951  WF_DU可调度率：0  WF_DP可调度率：0  BF_FF_DP可调度率：918
# 系统利用率：0.4  FF_DU可调度率：72  FF_DP可调度率：923  BF_DU可调度率：179  BF_DP可调度率：843  WF_DU可调度率：0  WF_DP可调度率：0  BF_FF_DP可调度率：770
# 系统利用率：0.42000000000000004  FF_DU可调度率：23  FF_DP可调度率：762  BF_DU可调度率：81  BF_DP可调度率：675  WF_DU可调度率：0  WF_DP可调度率：0  BF_FF_DP可调度率：554
# 系统利用率：0.44  FF_DU可调度率：4  FF_DP可调度率：482  BF_DU可调度率：28  BF_DP可调度率：423  WF_DU可调度率：0  WF_DP可调度率：0  BF_FF_DP可调度率：289
# 系统利用率：0.46  FF_DU可调度率：2  FF_DP可调度率：225  BF_DU可调度率：18  BF_DP可调度率：211  WF_DU可调度率：0  WF_DP可调度率：0  BF_FF_DP可调度率：113
# 系统利用率：0.48  FF_DU可调度率：0  FF_DP可调度率：71  BF_DU可调度率：3  BF_DP可调度率：74  WF_DU可调度率：0  WF_DP可调度率：0  BF_FF_DP可调度率：33
